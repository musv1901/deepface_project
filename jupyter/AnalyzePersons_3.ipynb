# %%
pip install -q deepface
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install -q opencv-contrib-python
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install -q image2base64
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install -q tensorflow
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install -q confluent-kafka
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
# imports
from deepface import DeepFace
import os
from PIL import Image
import numpy as np
import cv2
from matplotlib import pyplot as plt
import uuid
import pandas as pd
from image2base64.converters import base64_to_rgb, rgb2base64
import json
import traceback
import re
import time
import requests
from confluent_kafka import Consumer, Producer
import scipy
import multiprocessing as mp
import dask
from dask import delayed, visualize
from dask.distributed import Client
# Out:
# 2023-06-23 13:37:53.255990: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
# models
path = r"models/EDSR_x2.pb"
sr = cv2.dnn_superres.DnnSuperResImpl_create()
sr.readModel(path)
sr.setModel("edsr", 2)

# directories
db_path = r"stored_faces_db"

# Image resizing options
crop_increase_percent = 25
standard_height = 155
standard_width = 120

# db api
URL_TABLE = "https://gc7da7be5da2e70-g833jueqvvi5nhsa.adb.eu-frankfurt-1.oraclecloudapps.com/ords/admin/persons/"
URL_MODULE = "https://gc7da7be5da2e70-g833jueqvvi5nhsa.adb.eu-frankfurt-1.oraclecloudapps.com/ords/admin/operations/"

# kafka
consumer = Consumer({
    'bootstrap.servers': '192.168.70.40:9092',
    'group.id': 'py',
    'auto.offset.reset': 'earliest'
})
consumer.subscribe(['toAnalyze'])

del_consumer = Consumer({'bootstrap.servers': '192.168.70.40:9092',
    'group.id': 'py',
    'auto.offset.reset': 'earliest'
})
del_consumer.subscribe(['toDelete'])

producer = Producer({'bootstrap.servers': '192.168.70.40:9092'})

# thresholds
face_detection_conf = 0.9
face_recognition_distance = 120

# %%
def add_face_to_oracledb(face_dict, cropped_cv2):
    new_id = uuid.uuid4()
    #upscale_start = time.time()
    #upscale_img = upscale(cropped_cv2)
    #print("upscale img takes: " + str(time.time() - upscale_start))
    
    upscale_img = cropped_cv2
    
    data = {
        "in_id": str(new_id),
        "in_age": str(face_dict["age"]),
        "in_gender": face_dict["dominant_gender"],
        "in_emotion": face_dict["dominant_emotion"],
        "in_cropped_img": rgb2base64(upscale_img)
    }

    headers = {'Content-type': 'application/json'}
    response = requests.post(URL_MODULE + "insert_person", json.dumps(data), headers=headers)
    print("Add face to oracle db")

# %%
def refresh_face_in_oracledb(face_dict, id, cropped_cv2):
    #upscale_start = time.time()
    #upscale_img = upscale(cropped_cv2)
    #print("upscale img takes: " + str(time.time() - upscale_start))
    
    upscale_img = cropped_cv2
    
    data = {
        "in_id": str(id),
        "in_cropped_img": rgb2base64(upscale_img),
        "in_age": str(face_dict["age"]), 
        "in_gender": face_dict["dominant_gender"], 
        "in_emotion": face_dict["dominant_emotion"]
    }
    
    headers = {'Content-type': 'application/json'}
    response = requests.post(URL_MODULE + "update_person", json.dumps(data), headers=headers)
    print("Refresh face in oracle db")

# %%
def handle_db_communication(face_dict, id, cropped_cv2):
    upscale_img = upscale(cropped_cv2)
    
    data = {
        "in_id": str(id),
        "in_cropped_img": rgb2base64(upscale_img),
        "in_age": str(face_dict["age"]), 
        "in_gender": face_dict["dominant_gender"], 
        "in_emotion": face_dict["dominant_emotion"]
    }
    headers = {'Content-type': 'application/json'}
    
    if id is "NEW":
        data["in_id"] = str(uuid.uuid4())
        response = requests.post(URL_MODULE + "insert_person", json.dumps(data), headers=headers)
        print("Add face to oracle db")
    else:
        response = requests.post(URL_MODULE + "update_person", json.dumps(data), headers=headers)
        print("Refresh face in oracle db")

# %%
def batch_insert_faces(persons_data):
    headers = {'Content-type': 'application/json'}
    data = json.dumps(persons_data)
    print(data)
    
    try:
        response = requests.post(URL_MODULE + "insert_person", data=data, headers=headers)
        response.raise_for_status()
        print("Insert persons in Oracle DB")
    except requests.exceptions.RequestException as error:
        print("Error:", error)

# %%
def reset_is_present():
    response = requests.post(URL_MODULE + "reset_is_present")

# %%
def truncate_oracle_db():
    response = requests.delete(URL_MODULE + "truncate_table")
    response.raise_for_status()

# %%
def get_standard_size_img(cropped):
    return cv2.cvtColor(cv2.resize(cropped, (standard_width*2, standard_height*2)), cv2.COLOR_RGB2BGR)

# %%
def upscale(cropped_cv2):
    sr_upscale_np = sr.upsample(cropped_cv2)
    sr_upscale_np_corrected = cv2.cvtColor(sr_upscale_np, cv2.COLOR_RGB2BGR)

    return Image.fromarray(sr_upscale_np_corrected)

# %%
def check_existence(face_list, face_vector):
    if len(face_list) == 0:
        face_list.append({"vector":face_vector, "id":str(uuid.uuid4()), "time":time.time()})
        return "NEW"
    else:
        for index, element in enumerate(face_list):
            dist = scipy.spatial.distance.euclidean(face_vector, element["vector"])
            print("Checking face with list index" + str(index) + ", distance " + str(dist))
            if dist <= face_recognition_distance:
                print("Similiar face found with distance: " + str(dist) + " at index " + str(index))
                element["vector"] = face_vector
                element["time"] = time.time()
                face_list.pop(index)
                face_list.insert(0, element)
                return element["id"]
        print("No face found, new face added to list")
        face_list.insert(0, {"vector":face_vector, "id":str(uuid.uuid4()), "time":time.time()})
        return "NEW"

# %%
def create_new_face(analyze_features, cropped_cv2):
    upscale_img = upscale(cropped_cv2)
    return {
        "id": str(uuid.uuid4),
        "age": analyze_features["age"],
        "gender": analyze_features["dominant_gender"],
        "emotion": analyze_features["dominant_emotion"],
        "cropped_img": rgb2base64(upscale_img)
    }

# %%
def process_face(face):
    
    cropped = face["cropped"]
    
    analyze_start = time.time()
    analyze = DeepFace.analyze(img_path=cropped, actions=['age', 'gender','emotion'], 
                           detector_backend='skip', enforce_detection=False, silent=True)
    print("Analyzing 1 person: " + str(time.time()-analyze_start) + " secs")
    recog_start = time.time()
    emb = DeepFace.represent(img_path=cropped, detector_backend= 'skip', model_name="VGG-Face", 
                             enforce_detection=False)[0]["embedding"]
    result = check_existence(face_list, emb) 
    print("Face recognition 1 person: " + str(time.time()-recog_start) + " secs")

    oracle_start = time.time()
    w_increase = int(face['facial_area'].get('w') * crop_increase_percent / 100)
    h_increase = int(face['facial_area'].get('h') * crop_increase_percent / 100)
    x_new = x - w_increase // 2
    y_new = y - h_increase // 2
    w_new = w + w_increase
    h_new = h + h_increase
    
    cropped = get_standard_size_img(img[y_new:y_new + h_new, x_new:x_new + w_new, :])
    
    if result == "NEW":
        add_face_to_oracledb(face_dict=analyze[0], cropped_cv2=cropped)
    else:
        refresh_face_in_oracledb(face_dict=analyze[0], id=result, cropped_cv2=cropped)
    print("Oracle db actions: " + str(time.time()-oracle_start) + " secs")

# %%
face_list = []
num_workers = 10  # Specify the desired number of workers
client = Client(n_workers=num_workers)
truncate_oracle_db()

while True:
    try:
        del_msg = del_consumer.poll(1.0)
        
        if del_msg is not None:
            id = del_msg.value().decode('utf-8')
            for face in face_list:
                if face["id"] == id:
                    face_list.remove(face)
                    print("Face deleted")
                    break
      
        msg = consumer.poll(1.0)

        if msg is None:
            print("Waiting")
            continue
        if msg.error():
            print("Consumer error: {}".format(msg.error()))
            continue
        else:
            start = time.time()
            reset_is_present()
            #dict = json.loads(msg.value())
            #for base64 in dict["screens"]:
            
            base64 = msg.value()
            img = base64_to_rgb(base64, 'cv2')
            print("IMG SIZE: " + str(img.shape))
            start = time.time()
            extract_faces_start = time.time()
            faces = DeepFace.extract_faces(img_path=img, detector_backend="mtcnn", 
                                         enforce_detection=False)
            for face in faces:
                #if face["confidence"] < face_detection_conf:
                #    faces.remove(face)

                x = face['facial_area'].get('x')
                y = face['facial_area'].get('y')
                w = face['facial_area'].get('w')
                h = face['facial_area'].get('h')

                #w_increase = int(w * crop_increase_percent / 100)
                #h_increase = int(h * crop_increase_percent / 100)

                #x_new = x - w_increase // 2
                #y_new = y - h_increase // 2
                #w_new = w + w_increase
                #h_new = h + h_increase

                cropped = img[y:y+h, x:x+w, :]
                #cropped = get_standard_size_img(
                #    img[y_new:y_new + h_new, x_new:x_new + w_new, :])

                face["cropped"] = cropped 
                print(face["cropped"].shape)

            computations = [process_face(face) for face in faces]
            dask.compute(*computations)
                
            print("Time elapsed: " + str(time.time()-start))

            #producer.produce(topic="update_wall", value="DB refreshed")
            #producer.flush()
            #producer.produce(topic="update_feeds", value="DB refreshed")
            #producer.flush()
    except Exception as e:
        traceback.print_exc()
        continue
client.close()
# Out:
# Process Dask Worker process (from Nanny):
# 2023-06-23 13:52:35,085 - distributed.nanny - ERROR - Worker process died unexpectedly
# Process Dask Worker process (from Nanny):
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/conda/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/distributed/process.py", line 202, in _run
#     target(*args, **kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/distributed/nanny.py", line 999, in _run
#     asyncio.run(run())
#   File "/opt/conda/lib/python3.10/asyncio/runners.py", line 44, in run
#     return loop.run_until_complete(main)
#   File "/opt/conda/lib/python3.10/asyncio/base_events.py", line 636, in run_until_complete
#     self.run_forever()
#   File "/opt/conda/lib/python3.10/asyncio/base_events.py", line 603, in run_forever
#     self._run_once()
#   File "/opt/conda/lib/python3.10/asyncio/base_events.py", line 1871, in _run_once
#     event_list = self._selector.select(timeout)
#   File "/opt/conda/lib/python3.10/selectors.py", line 469, in select
#     fd_event_list = self._selector.poll(timeout, max_ev)
# KeyboardInterrupt
# Process Dask Worker process (from Nanny):
# Process Dask Worker process (from Nanny):
# 2023-06-23 13:52:35,086 - distributed.nanny - ERROR - Worker process died unexpectedly
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/conda/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/distributed/process.py", line 202, in _run
#     target(*args, **kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/distributed/nanny.py", line 999, in _run
#     asyncio.run(run())
#   File "/opt/conda/lib/python3.10/asyncio/runners.py", line 44, in run
#     return loop.run_until_complete(main)
#   File "/opt/conda/lib/python3.10/asyncio/base_events.py", line 636, in run_until_complete
#     self.run_forever()
#   File "/opt/conda/lib/python3.10/asyncio/base_events.py", line 603, in run_forever
#     self._run_once()
#   File "/opt/conda/lib/python3.10/asyncio/base_events.py", line 1871, in _run_once
#     event_list = self._selector.select(timeout)
#   File "/opt/conda/lib/python3.10/selectors.py", line 469, in select
#     fd_event_list = self._selector.poll(timeout, max_ev)
# KeyboardInterrupt
# Traceback (most recent call last):
# Process Dask Worker process (from Nanny):
#   File "/opt/conda/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/conda/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/distributed/process.py", line 202, in _run
#     target(*args, **kwargs)
# 2023-06-23 13:52:35,087 - distributed.nanny - ERROR - Worker process died unexpectedly
#   File "/opt/conda/lib/python3.10/site-packages/distributed/nanny.py", line 999, in _run
#     asyncio.run(run())
#   File "/opt/conda/lib/python3.10/asyncio/runners.py", line 44, in run
#     return loop.run_until_complete(main)
#   File "/opt/conda/lib/python3.10/asyncio/base_events.py", line 636, in run_until_complete
#     self.run_forever()
#   File "/opt/conda/lib/python3.10/asyncio/base_events.py", line 603, in run_forever
#     self._run_once()
#   File "/opt/conda/lib/python3.10/asyncio/base_events.py", line 1871, in _run_once
#     event_list = self._selector.select(timeout)
#   File "/opt/conda/lib/python3.10/selectors.py", line 469, in select
#     fd_event_list = self._selector.poll(timeout, max_ev)
# KeyboardInterrupt
# Process Dask Worker process (from Nanny):
# Traceback (most recent call last):
# Process Dask Worker process (from Nanny):
#   File "/opt/conda/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/conda/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/distributed/process.py", line 202, in _run
#     target(*args, **kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/distributed/nanny.py", line 999, in _run
#     asyncio.run(run())
#   File "/opt/conda/lib/python3.10/asyncio/runners.py", line 44, in run
#     return loop.run_until_complete(main)
#   File "/opt/conda/lib/python3.10/asyncio/base_events.py", line 636, in run_until_complete
#     self.run_forever()
#   File "/opt/conda/lib/python3.10/asyncio/base_events.py", line 603, in run_forever
#     self._run_once()
#   File "/opt/conda/lib/python3.10/asyncio/base_events.py", line 1871, in _run_once
#     event_list = self._selector.select(timeout)
#   File "/opt/conda/lib/python3.10/selectors.py", line 469, in select
#     fd_event_list = self._selector.poll(timeout, max_ev)
# Process Dask Worker process (from Nanny):
# KeyboardInterrupt
# 2023-06-23 13:52:35,088 - distributed.nanny - ERROR - Worker process died unexpectedly
# 2023-06-23 13:52:35,088 - distributed.nanny - ERROR - Worker process died unexpectedly
# Process Dask Worker process (from Nanny):
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/conda/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/distributed/process.py", line 202, in _run
#     target(*args, **kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/distributed/nanny.py", line 999, in _run
#     asyncio.run(run())
#   File "/opt/conda/lib/python3.10/asyncio/runners.py", line 44, in run
#     return loop.run_until_complete(main)
#   File "/opt/conda/lib/python3.10/asyncio/base_events.py", line 636, in run_until_complete
#     self.run_forever()
#   File "/opt/conda/lib/python3.10/asyncio/base_events.py", line 603, in run_forever
#     self._run_once()
#   File "/opt/conda/lib/python3.10/asyncio/base_events.py", line 1871, in _run_once
#     event_list = self._selector.select(timeout)
#   File "/opt/conda/lib/python3.10/selectors.py", line 469, in select
#     fd_event_list = self._selector.poll(timeout, max_ev)
# KeyboardInterrupt
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/conda/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/distributed/process.py", line 202, in _run
#     target(*args, **kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/distributed/nanny.py", line 999, in _run
#     asyncio.run(run())
#   File "/opt/conda/lib/python3.10/asyncio/runners.py", line 44, in run
#     return loop.run_until_complete(main)
#   File "/opt/conda/lib/python3.10/asyncio/base_events.py", line 636, in run_until_complete
#     self.run_forever()
#   File "/opt/conda/lib/python3.10/asyncio/base_events.py", line 603, in run_forever
#     self._run_once()
#   File "/opt/conda/lib/python3.10/asyncio/base_events.py", line 1871, in _run_once
#     event_list = self._selector.select(timeout)
#   File "/opt/conda/lib/python3.10/selectors.py", line 469, in select
#     fd_event_list = self._selector.poll(timeout, max_ev)
# KeyboardInterrupt
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/conda/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/distributed/process.py", line 202, in _run
#     target(*args, **kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/distributed/nanny.py", line 999, in _run
#     asyncio.run(run())
#   File "/opt/conda/lib/python3.10/asyncio/runners.py", line 44, in run
#     return loop.run_until_complete(main)
#   File "/opt/conda/lib/python3.10/asyncio/base_events.py", line 636, in run_until_complete
#     self.run_forever()
#   File "/opt/conda/lib/python3.10/asyncio/base_events.py", line 603, in run_forever
#     self._run_once()
#   File "/opt/conda/lib/python3.10/asyncio/base_events.py", line 1871, in _run_once
#     event_list = self._selector.select(timeout)
#   File "/opt/conda/lib/python3.10/selectors.py", line 469, in select
#     fd_event_list = self._selector.poll(timeout, max_ev)
# KeyboardInterrupt
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/conda/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/distributed/process.py", line 202, in _run
#     target(*args, **kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/distributed/nanny.py", line 999, in _run
#     asyncio.run(run())
#   File "/opt/conda/lib/python3.10/asyncio/runners.py", line 44, in run
#     return loop.run_until_complete(main)
#   File "/opt/conda/lib/python3.10/asyncio/base_events.py", line 636, in run_until_complete
#     self.run_forever()
#   File "/opt/conda/lib/python3.10/asyncio/base_events.py", line 603, in run_forever
#     self._run_once()
#   File "/opt/conda/lib/python3.10/asyncio/base_events.py", line 1871, in _run_once
#     event_list = self._selector.select(timeout)
#   File "/opt/conda/lib/python3.10/selectors.py", line 469, in select
#     fd_event_list = self._selector.poll(timeout, max_ev)
# KeyboardInterrupt
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/conda/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/distributed/process.py", line 202, in _run
#     target(*args, **kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/distributed/nanny.py", line 999, in _run
#     asyncio.run(run())
#   File "/opt/conda/lib/python3.10/asyncio/runners.py", line 44, in run
#     return loop.run_until_complete(main)
#   File "/opt/conda/lib/python3.10/asyncio/base_events.py", line 636, in run_until_complete
#     self.run_forever()
#   File "/opt/conda/lib/python3.10/asyncio/base_events.py", line 603, in run_forever
#     self._run_once()
#   File "/opt/conda/lib/python3.10/asyncio/base_events.py", line 1871, in _run_once
#     event_list = self._selector.select(timeout)
#   File "/opt/conda/lib/python3.10/selectors.py", line 469, in select
#     fd_event_list = self._selector.poll(timeout, max_ev)
# KeyboardInterrupt
# Process Dask Worker process (from Nanny):
# 2023-06-23 13:52:35,092 - distributed.nanny - ERROR - Worker process died unexpectedly
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/conda/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/distributed/process.py", line 202, in _run
#     target(*args, **kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/distributed/nanny.py", line 999, in _run
#     asyncio.run(run())
#   File "/opt/conda/lib/python3.10/asyncio/runners.py", line 44, in run
#     return loop.run_until_complete(main)
#   File "/opt/conda/lib/python3.10/asyncio/base_events.py", line 636, in run_until_complete
#     self.run_forever()
#   File "/opt/conda/lib/python3.10/asyncio/base_events.py", line 603, in run_forever
#     self._run_once()
#   File "/opt/conda/lib/python3.10/asyncio/base_events.py", line 1871, in _run_once
#     event_list = self._selector.select(timeout)
#   File "/opt/conda/lib/python3.10/selectors.py", line 469, in select
#     fd_event_list = self._selector.poll(timeout, max_ev)
# KeyboardInterrupt
# IMG SIZE: (720, 1280, 3)
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 13ms/step
# 3/3 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 24ms/step
# (88, 65, 3)
# (156, 108, 3)
# Analyzing 1 person: 0.3116486072540283 secs
# Face recognition 1 person: 0.13958096504211426 secs
# Add face to oracle db
# Oracle db actions: 0.2775123119354248 secs
# Analyzing 1 person: 0.2780907154083252 secs
# Checking face with list index0, distance 28.50797100223663
# Similiar face found with distance: 28.50797100223663 at index 0
# Face recognition 1 person: 0.1295170783996582 secs
# Refresh face in oracle db
# Oracle db actions: 0.44907069206237793 secs
# Time elapsed: 2.370495557785034
# IMG SIZE: (720, 1280, 3)
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 13ms/step
# 2/2 [==============================] - 0s 6ms/step
# (720, 1280, 3)
# Analyzing 1 person: 0.27812838554382324 secs
# Checking face with list index0, distance 89.01730674218747
# Similiar face found with distance: 89.01730674218747 at index 0
# Face recognition 1 person: 0.12035059928894043 secs
# Refresh face in oracle db
# Oracle db actions: 0.17032647132873535 secs
# Time elapsed: 1.2658350467681885
# IMG SIZE: (720, 1280, 3)
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 3/3 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 17ms/step
# (219, 155, 3)
# (80, 63, 3)
# Analyzing 1 person: 0.2943875789642334 secs
# Checking face with list index0, distance 100.21010240983833
# Similiar face found with distance: 100.21010240983833 at index 0
# Face recognition 1 person: 0.12466096878051758 secs
# Refresh face in oracle db
# Oracle db actions: 0.20227646827697754 secs
# Analyzing 1 person: 0.2781233787536621 secs
# Checking face with list index0, distance 53.051411148821785
# Similiar face found with distance: 53.051411148821785 at index 0
# Face recognition 1 person: 0.11674118041992188 secs
# Refresh face in oracle db
# Oracle db actions: 0.1760704517364502 secs
# Time elapsed: 1.9158234596252441
# IMG SIZE: (720, 1280, 3)
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 3/3 [==============================] - 0s 3ms/step
# (720, 1280, 3)
# Analyzing 1 person: 0.31816601753234863 secs
# Checking face with list index0, distance 96.98382760428302
# Similiar face found with distance: 96.98382760428302 at index 0
# Face recognition 1 person: 0.5699014663696289 secs
# Refresh face in oracle db
# Oracle db actions: 0.17372441291809082 secs
# Time elapsed: 1.714301586151123
# IMG SIZE: (720, 1280, 3)
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 15ms/step
# 3/3 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 29ms/step
# (106, 87, 3)
# Analyzing 1 person: 0.30911898612976074 secs
# Checking face with list index0, distance 89.6374003646671
# Similiar face found with distance: 89.6374003646671 at index 0
# Face recognition 1 person: 0.13667607307434082 secs
# Refresh face in oracle db
# Oracle db actions: 0.17671561241149902 secs
# Time elapsed: 1.4723594188690186
# IMG SIZE: (720, 1280, 3)
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 13ms/step
# 2/2 [==============================] - 0s 8ms/step
# (720, 1280, 3)
# Analyzing 1 person: 0.3094487190246582 secs
# Checking face with list index0, distance 90.76814825184124
# Similiar face found with distance: 90.76814825184124 at index 0
# Face recognition 1 person: 0.12392973899841309 secs
# Refresh face in oracle db
# Oracle db actions: 0.19466209411621094 secs
# Time elapsed: 1.321106195449829
# IMG SIZE: (720, 1280, 3)
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 3/3 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 16ms/step
# (110, 86, 3)
# Analyzing 1 person: 0.30124902725219727 secs
# Checking face with list index0, distance 91.52375512110268
# Similiar face found with distance: 91.52375512110268 at index 0
# Face recognition 1 person: 0.12007260322570801 secs
# Refresh face in oracle db
# Oracle db actions: 0.175734281539917 secs
# Time elapsed: 1.3991987705230713
# IMG SIZE: (720, 1280, 3)
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 14ms/step
# 3/3 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 17ms/step
# (720, 1280, 3)
# Analyzing 1 person: 0.3993816375732422 secs
# Checking face with list index0, distance 91.43303352627264
# Similiar face found with distance: 91.43303352627264 at index 0
# Face recognition 1 person: 0.1636064052581787 secs
# Refresh face in oracle db
# Oracle db actions: 0.4014716148376465 secs
# Time elapsed: 1.8318572044372559
# IMG SIZE: (720, 1280, 3)
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 15ms/step
# 3/3 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 16ms/step
# (103, 72, 3)
# (108, 69, 3)
# Analyzing 1 person: 0.2802915573120117 secs
# Checking face with list index0, distance 94.51745670780723
# Similiar face found with distance: 94.51745670780723 at index 0
# Face recognition 1 person: 0.157975435256958 secs
# Refresh face in oracle db
# Oracle db actions: 0.1758420467376709 secs
# Analyzing 1 person: 0.2692606449127197 secs
# Checking face with list index0, distance 40.58674861957955
# Similiar face found with distance: 40.58674861957955 at index 0
# Face recognition 1 person: 0.1402900218963623 secs
# Refresh face in oracle db
# Oracle db actions: 0.17494416236877441 secs
# Time elapsed: 1.937009572982788
# IMG SIZE: (720, 1280, 3)
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 14ms/step
# 2/2 [==============================] - 0s 7ms/step
# (720, 1280, 3)
# Analyzing 1 person: 0.2651820182800293 secs
# Checking face with list index0, distance 87.31328477433871
# Similiar face found with distance: 87.31328477433871 at index 0
# Face recognition 1 person: 0.1277477741241455 secs
# Refresh face in oracle db
# Oracle db actions: 0.1764521598815918 secs
# Time elapsed: 1.2935338020324707
# IMG SIZE: (720, 1280, 3)
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 3/3 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 17ms/step
# (100, 69, 3)
# Analyzing 1 person: 0.3000302314758301 secs
# Checking face with list index0, distance 92.2754240231742
# Similiar face found with distance: 92.2754240231742 at index 0
# Face recognition 1 person: 0.1369483470916748 secs
# Refresh face in oracle db
# Oracle db actions: 0.18095803260803223 secs
# Time elapsed: 1.4030497074127197
# IMG SIZE: (720, 1280, 3)
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 12ms/step
# 2/2 [==============================] - 0s 4ms/step
# (720, 1280, 3)
# Analyzing 1 person: 0.26805996894836426 secs
# Checking face with list index0, distance 91.96986118429697
# Similiar face found with distance: 91.96986118429697 at index 0
# Face recognition 1 person: 0.12815475463867188 secs
# Refresh face in oracle db
# Oracle db actions: 0.31362318992614746 secs
# Time elapsed: 1.4357354640960693
# IMG SIZE: (720, 1280, 3)
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 12ms/step
# 3/3 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 22ms/step
# (102, 75, 3)
# (102, 60, 3)
# Analyzing 1 person: 0.29818010330200195 secs
# Checking face with list index0, distance 87.99864983237357
# Similiar face found with distance: 87.99864983237357 at index 0
# Face recognition 1 person: 0.11152410507202148 secs
# Refresh face in oracle db
# Oracle db actions: 0.1741926670074463 secs
# Analyzing 1 person: 0.30138564109802246 secs
# Checking face with list index0, distance 38.561610341860664
# Similiar face found with distance: 38.561610341860664 at index 0
# Face recognition 1 person: 0.12366580963134766 secs
# Refresh face in oracle db
# Oracle db actions: 0.18311667442321777 secs
# Time elapsed: 1.9837825298309326
# IMG SIZE: (720, 1280, 3)
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 12ms/step
# 3/3 [==============================] - 0s 5ms/step
# (720, 1280, 3)
# Analyzing 1 person: 0.2853715419769287 secs
# Checking face with list index0, distance 77.70757206210163
# Similiar face found with distance: 77.70757206210163 at index 0
# Face recognition 1 person: 0.12266921997070312 secs
# Refresh face in oracle db
# Oracle db actions: 0.16573405265808105 secs
# Time elapsed: 1.2965641021728516
# IMG SIZE: (720, 1280, 3)
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 12ms/step
# 3/3 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 16ms/step
# (99, 80, 3)
# (99, 55, 3)
# Analyzing 1 person: 0.33815741539001465 secs
# Checking face with list index0, distance 90.10404452184443
# Similiar face found with distance: 90.10404452184443 at index 0
# Face recognition 1 person: 0.1173093318939209 secs
# Refresh face in oracle db
# Oracle db actions: 0.18447375297546387 secs
# Analyzing 1 person: 0.2942078113555908 secs
# Checking face with list index0, distance 44.33997381433637
# Similiar face found with distance: 44.33997381433637 at index 0
# Face recognition 1 person: 0.1151576042175293 secs
# Refresh face in oracle db
# Oracle db actions: 0.16826677322387695 secs
# Time elapsed: 1.9245860576629639
# IMG SIZE: (720, 1280, 3)
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 12ms/step
# 3/3 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 16ms/step
# (35, 25, 3)
# Analyzing 1 person: 0.2991764545440674 secs
# Checking face with list index0, distance 24.512383726065828
# Similiar face found with distance: 24.512383726065828 at index 0
# Face recognition 1 person: 0.1094200611114502 secs
# Refresh face in oracle db
# Oracle db actions: 0.17452144622802734 secs
# Time elapsed: 1.3909039497375488
# IMG SIZE: (720, 1280, 3)
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 3/3 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 25ms/step
# (167, 135, 3)
# (109, 91, 3)
# Analyzing 1 person: 0.29695653915405273 secs
# Checking face with list index0, distance 48.588518122550724
# Similiar face found with distance: 48.588518122550724 at index 0
# Face recognition 1 person: 0.1269974708557129 secs
# Refresh face in oracle db
# Oracle db actions: 0.18527722358703613 secs
# Analyzing 1 person: 0.2945868968963623 secs
# Checking face with list index0, distance 58.58246525725564
# Similiar face found with distance: 58.58246525725564 at index 0
# Face recognition 1 person: 0.12812447547912598 secs
# Refresh face in oracle db
# Oracle db actions: 0.1735820770263672 secs
# Time elapsed: 1.974472999572754
# IMG SIZE: (720, 1280, 3)
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 3/3 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 15ms/step
# (720, 1280, 3)
# Analyzing 1 person: 0.26905202865600586 secs
# Checking face with list index0, distance 92.37935691255872
# Similiar face found with distance: 92.37935691255872 at index 0
# Face recognition 1 person: 0.1412944793701172 secs
# Refresh face in oracle db
# Oracle db actions: 0.2734251022338867 secs
# Time elapsed: 1.454639196395874
# IMG SIZE: (720, 1280, 3)
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 18ms/step
# 4/4 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 22ms/step
# (100, 84, 3)
# Analyzing 1 person: 0.32765984535217285 secs
# Checking face with list index0, distance 91.25083356537691
# Similiar face found with distance: 91.25083356537691 at index 0
# Face recognition 1 person: 0.11969757080078125 secs
# Refresh face in oracle db
# Oracle db actions: 0.17752647399902344 secs
# Time elapsed: 1.480290174484253
# IMG SIZE: (720, 1280, 3)
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 12ms/step
# 3/3 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 14ms/step
# (720, 1280, 3)
# Analyzing 1 person: 0.2976086139678955 secs
# Checking face with list index0, distance 91.33819368837129
# Similiar face found with distance: 91.33819368837129 at index 0
# Face recognition 1 person: 0.11625361442565918 secs
# Refresh face in oracle db
# Oracle db actions: 0.18247270584106445 secs
# Time elapsed: 1.3719468116760254
# IMG SIZE: (720, 1280, 3)
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 4/4 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 22ms/step
# (100, 84, 3)
# (162, 117, 3)
# Analyzing 1 person: 0.2748100757598877 secs
# Checking face with list index0, distance 103.16737199086646
# Similiar face found with distance: 103.16737199086646 at index 0
# Face recognition 1 person: 0.12050628662109375 secs
# Refresh face in oracle db
# Oracle db actions: 0.20058631896972656 secs
# Analyzing 1 person: 0.2896463871002197 secs
# Checking face with list index0, distance 80.91043551567844
# Similiar face found with distance: 80.91043551567844 at index 0
# Face recognition 1 person: 0.11321473121643066 secs
# Refresh face in oracle db
# Oracle db actions: 0.17424821853637695 secs
# Time elapsed: 1.9136912822723389
# IMG SIZE: (720, 1280, 3)
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 13ms/step
# 3/3 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 14ms/step
# (720, 1280, 3)
# Analyzing 1 person: 0.32883381843566895 secs
# Checking face with list index0, distance 97.89641248766891
# Similiar face found with distance: 97.89641248766891 at index 0
# Face recognition 1 person: 0.15378832817077637 secs
# Refresh face in oracle db
# Oracle db actions: 0.22068071365356445 secs
# Time elapsed: 1.5086078643798828
# IMG SIZE: (720, 1280, 3)
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 3/3 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 17ms/step
# (179, 136, 3)
# (108, 83, 3)
# Analyzing 1 person: 0.2803213596343994 secs
# Checking face with list index0, distance 140.1135397305602
# No face found, new face added to list
# Face recognition 1 person: 0.1324763298034668 secs
# Add face to oracle db
# Oracle db actions: 0.1856212615966797 secs
# Analyzing 1 person: 0.2857680320739746 secs
# Checking face with list index0, distance 116.19220137411968
# Similiar face found with distance: 116.19220137411968 at index 0
# Face recognition 1 person: 0.12002086639404297 secs
# Refresh face in oracle db
# Oracle db actions: 0.1709895133972168 secs
# Time elapsed: 1.8531579971313477
# IMG SIZE: (720, 1280, 3)
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 13ms/step
# 2/2 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 15ms/step
# (720, 1280, 3)
# Analyzing 1 person: 0.2875862121582031 secs
# Checking face with list index0, distance 86.59166408678439
# Similiar face found with distance: 86.59166408678439 at index 0
# Face recognition 1 person: 0.11537551879882812 secs
# Refresh face in oracle db
# Oracle db actions: 0.1780407428741455 secs
# Time elapsed: 1.3816421031951904
# IMG SIZE: (720, 1280, 3)
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 3/3 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 29ms/step
# (185, 138, 3)
# (99, 75, 3)
# Analyzing 1 person: 0.2782919406890869 secs
# Checking face with list index0, distance 141.59633105032069
# Checking face with list index1, distance 141.52599600638226
# No face found, new face added to list
# Face recognition 1 person: 0.12335586547851562 secs
# Add face to oracle db
# Oracle db actions: 0.17803955078125 secs
# Analyzing 1 person: 0.44926881790161133 secs
# Checking face with list index0, distance 122.28879995707851
# Checking face with list index1, distance 88.2574000535227
# Similiar face found with distance: 88.2574000535227 at index 1
# Face recognition 1 person: 0.16242098808288574 secs
# Refresh face in oracle db
# Oracle db actions: 0.23139500617980957 secs
# Time elapsed: 2.1710095405578613
# IMG SIZE: (720, 1280, 3)
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 12ms/step
# 3/3 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 52ms/step
# (720, 1280, 3)
# Analyzing 1 person: 0.31284356117248535 secs
# Checking face with list index0, distance 85.256619561824
# Similiar face found with distance: 85.256619561824 at index 0
# Face recognition 1 person: 0.12826895713806152 secs
# Refresh face in oracle db
# Oracle db actions: 0.1741039752960205 secs
# Time elapsed: 1.393385410308838
# IMG SIZE: (720, 1280, 3)
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 5/5 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 23ms/step
# (97, 79, 3)
# (184, 133, 3)
# Analyzing 1 person: 0.3265249729156494 secs
# Checking face with list index0, distance 123.44439311171716
# Checking face with list index1, distance 108.22360124683331
# Similiar face found with distance: 108.22360124683331 at index 1
# Face recognition 1 person: 0.12775015830993652 secs
# Refresh face in oracle db
# Oracle db actions: 0.1763017177581787 secs
# Analyzing 1 person: 0.27945876121520996 secs
# Checking face with list index0, distance 96.88400779872396
# Similiar face found with distance: 96.88400779872396 at index 0
# Face recognition 1 person: 0.1222829818725586 secs
# Refresh face in oracle db
# Oracle db actions: 0.18600749969482422 secs
# Time elapsed: 1.9391849040985107
# IMG SIZE: (720, 1280, 3)
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 16ms/step
# 3/3 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 14ms/step
# (720, 1280, 3)
# Analyzing 1 person: 0.2841622829437256 secs
# Checking face with list index0, distance 94.99936633366354
# Similiar face found with distance: 94.99936633366354 at index 0
# Face recognition 1 person: 0.12471890449523926 secs
# Refresh face in oracle db
# Oracle db actions: 0.18027520179748535 secs
# Time elapsed: 1.340017318725586
# IMG SIZE: (720, 1280, 3)
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 13ms/step
# 3/3 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 17ms/step
# (100, 79, 3)
# (171, 124, 3)
# Analyzing 1 person: 0.2724161148071289 secs
# Checking face with list index0, distance 140.8873693471358
# Checking face with list index1, distance 140.34221605760263
# Checking face with list index2, distance 142.04869031621809
# No face found, new face added to list
# Face recognition 1 person: 0.14560842514038086 secs
# Add face to oracle db
# Oracle db actions: 0.20691680908203125 secs
# Analyzing 1 person: 0.2953634262084961 secs
# Checking face with list index0, distance 130.56834814515807
# Checking face with list index1, distance 90.78710135015797
# Similiar face found with distance: 90.78710135015797 at index 1
# Face recognition 1 person: 0.12925410270690918 secs
# Refresh face in oracle db
# Oracle db actions: 0.1660759449005127 secs
# Time elapsed: 1.9646389484405518
# IMG SIZE: (720, 1280, 3)
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 56ms/step
# 3/3 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 17ms/step
# (720, 1280, 3)
# Analyzing 1 person: 0.27227282524108887 secs
# Checking face with list index0, distance 89.67628268578855
# Similiar face found with distance: 89.67628268578855 at index 0
# Face recognition 1 person: 0.11536121368408203 secs
# Refresh face in oracle db
# Oracle db actions: 0.17064428329467773 secs
# Time elapsed: 1.2952961921691895
# IMG SIZE: (720, 1280, 3)
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 12ms/step
# 3/3 [==============================] - 0s 4ms/step
# 1/1 [==============================] - 0s 16ms/step
# (170, 117, 3)
# (91, 80, 3)
# Analyzing 1 person: 0.283693790435791 secs
# Checking face with list index0, distance 89.0353121796203
# Similiar face found with distance: 89.0353121796203 at index 0
# Face recognition 1 person: 0.1141517162322998 secs
# Refresh face in oracle db
# Oracle db actions: 0.16742420196533203 secs
# Analyzing 1 person: 0.31487345695495605 secs
# Checking face with list index0, distance 101.57660152388897
# Similiar face found with distance: 101.57660152388897 at index 0
# Face recognition 1 person: 0.1681656837463379 secs
# Refresh face in oracle db
# Oracle db actions: 0.17517399787902832 secs
# Time elapsed: 1.9394073486328125
# IMG SIZE: (720, 1280, 3)
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# ...
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/distributed/process.py", line 202, in _run
#     target(*args, **kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/distributed/nanny.py", line 973, in _run
#     with contextlib.ExitStack() as stack:
#   File "/opt/conda/lib/python3.10/contextlib.py", line 576, in __exit__
#     raise exc_details[1]
#   File "/opt/conda/lib/python3.10/contextlib.py", line 561, in __exit__
#     if cb(*exc_details):
#   File "/opt/conda/lib/python3.10/contextlib.py", line 449, in _exit_wrapper
#     callback(*args, **kwds)
#   File "/opt/conda/lib/python3.10/threading.py", line 1100, in join
#     self._wait_for_tstate_lock(timeout=max(timeout, 0))
#   File "/opt/conda/lib/python3.10/threading.py", line 1116, in _wait_for_tstate_lock
#     if lock.acquire(block, timeout):
# KeyboardInterrupt
#   File "/opt/conda/lib/python3.10/site-packages/distributed/nanny.py", line 999, in _run
#     asyncio.run(run())
#   File "/opt/conda/lib/python3.10/asyncio/runners.py", line 44, in run
#     return loop.run_until_complete(main)
#   File "/opt/conda/lib/python3.10/asyncio/base_events.py", line 636, in run_until_complete
#     self.run_forever()
#   File "/opt/conda/lib/python3.10/asyncio/base_events.py", line 603, in run_forever
#     self._run_once()
#   File "/opt/conda/lib/python3.10/asyncio/base_events.py", line 1871, in _run_once
#     event_list = self._selector.select(timeout)
#   File "/opt/conda/lib/python3.10/selectors.py", line 469, in select
#     fd_event_list = self._selector.poll(timeout, max_ev)
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/conda/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/distributed/process.py", line 202, in _run
#     target(*args, **kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/distributed/nanny.py", line 973, in _run
#     with contextlib.ExitStack() as stack:
#   File "/opt/conda/lib/python3.10/contextlib.py", line 576, in __exit__
#     raise exc_details[1]
#   File "/opt/conda/lib/python3.10/contextlib.py", line 561, in __exit__
#     if cb(*exc_details):
#   File "/opt/conda/lib/python3.10/contextlib.py", line 449, in _exit_wrapper
#     callback(*args, **kwds)
#   File "/opt/conda/lib/python3.10/threading.py", line 1100, in join
#     self._wait_for_tstate_lock(timeout=max(timeout, 0))
#   File "/opt/conda/lib/python3.10/threading.py", line 1116, in _wait_for_tstate_lock
#     if lock.acquire(block, timeout):
#   File "/opt/conda/lib/python3.10/site-packages/distributed/nanny.py", line 999, in _run
#     asyncio.run(run())
# KeyboardInterrupt
#   File "/opt/conda/lib/python3.10/asyncio/runners.py", line 44, in run
#     return loop.run_until_complete(main)
#   File "/opt/conda/lib/python3.10/asyncio/base_events.py", line 636, in run_until_complete
#     self.run_forever()
#   File "/opt/conda/lib/python3.10/asyncio/base_events.py", line 603, in run_forever
#     self._run_once()
#   File "/opt/conda/lib/python3.10/asyncio/base_events.py", line 1871, in _run_once
#     event_list = self._selector.select(timeout)
#   File "/opt/conda/lib/python3.10/selectors.py", line 469, in select
#     fd_event_list = self._selector.poll(timeout, max_ev)
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/conda/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/distributed/process.py", line 202, in _run
#     target(*args, **kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/distributed/nanny.py", line 973, in _run
#     with contextlib.ExitStack() as stack:
#   File "/opt/conda/lib/python3.10/contextlib.py", line 576, in __exit__
#     raise exc_details[1]
#   File "/opt/conda/lib/python3.10/contextlib.py", line 561, in __exit__
#     if cb(*exc_details):
#   File "/opt/conda/lib/python3.10/contextlib.py", line 449, in _exit_wrapper
#     callback(*args, **kwds)
#   File "/opt/conda/lib/python3.10/threading.py", line 1100, in join
#     self._wait_for_tstate_lock(timeout=max(timeout, 0))
#   File "/opt/conda/lib/python3.10/threading.py", line 1116, in _wait_for_tstate_lock
#     if lock.acquire(block, timeout):
# KeyboardInterrupt
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/distributed/nanny.py", line 999, in _run
#     asyncio.run(run())
#   File "/opt/conda/lib/python3.10/asyncio/runners.py", line 44, in run
#     return loop.run_until_complete(main)
#   File "/opt/conda/lib/python3.10/asyncio/base_events.py", line 636, in run_until_complete
#     self.run_forever()
#   File "/opt/conda/lib/python3.10/asyncio/base_events.py", line 603, in run_forever
#     self._run_once()
#   File "/opt/conda/lib/python3.10/asyncio/base_events.py", line 1871, in _run_once
#     event_list = self._selector.select(timeout)
#   File "/opt/conda/lib/python3.10/selectors.py", line 469, in select
#     fd_event_list = self._selector.poll(timeout, max_ev)
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/conda/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/distributed/process.py", line 202, in _run
#     target(*args, **kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/distributed/nanny.py", line 973, in _run
#     with contextlib.ExitStack() as stack:
#   File "/opt/conda/lib/python3.10/contextlib.py", line 576, in __exit__
#     raise exc_details[1]
#   File "/opt/conda/lib/python3.10/contextlib.py", line 561, in __exit__
#     if cb(*exc_details):
#   File "/opt/conda/lib/python3.10/contextlib.py", line 449, in _exit_wrapper
#     callback(*args, **kwds)
#   File "/opt/conda/lib/python3.10/threading.py", line 1100, in join
#     self._wait_for_tstate_lock(timeout=max(timeout, 0))
#   File "/opt/conda/lib/python3.10/threading.py", line 1116, in _wait_for_tstate_lock
#     if lock.acquire(block, timeout):
# KeyboardInterrupt
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/distributed/nanny.py", line 999, in _run
#     asyncio.run(run())
#   File "/opt/conda/lib/python3.10/asyncio/runners.py", line 44, in run
#     return loop.run_until_complete(main)
#   File "/opt/conda/lib/python3.10/asyncio/base_events.py", line 636, in run_until_complete
#     self.run_forever()
#   File "/opt/conda/lib/python3.10/asyncio/base_events.py", line 603, in run_forever
#     self._run_once()
#   File "/opt/conda/lib/python3.10/asyncio/base_events.py", line 1871, in _run_once
#     event_list = self._selector.select(timeout)
#   File "/opt/conda/lib/python3.10/selectors.py", line 469, in select
#     fd_event_list = self._selector.poll(timeout, max_ev)
# Traceback (most recent call last):
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/distributed/nanny.py", line 999, in _run
#     asyncio.run(run())
#   File "/opt/conda/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/conda/lib/python3.10/asyncio/runners.py", line 44, in run
#     return loop.run_until_complete(main)
#   File "/opt/conda/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/conda/lib/python3.10/asyncio/base_events.py", line 636, in run_until_complete
#     self.run_forever()
#   File "/opt/conda/lib/python3.10/site-packages/distributed/process.py", line 202, in _run
#     target(*args, **kwargs)
#   File "/opt/conda/lib/python3.10/asyncio/base_events.py", line 603, in run_forever
#     self._run_once()
#   File "/opt/conda/lib/python3.10/site-packages/distributed/nanny.py", line 973, in _run
#     with contextlib.ExitStack() as stack:
#   File "/opt/conda/lib/python3.10/asyncio/base_events.py", line 1871, in _run_once
#     event_list = self._selector.select(timeout)
#   File "/opt/conda/lib/python3.10/contextlib.py", line 576, in __exit__
#     raise exc_details[1]
#   File "/opt/conda/lib/python3.10/contextlib.py", line 561, in __exit__
#     if cb(*exc_details):
#   File "/opt/conda/lib/python3.10/selectors.py", line 469, in select
#     fd_event_list = self._selector.poll(timeout, max_ev)
#   File "/opt/conda/lib/python3.10/contextlib.py", line 449, in _exit_wrapper
#     callback(*args, **kwds)
#   File "/opt/conda/lib/python3.10/threading.py", line 1100, in join
#     self._wait_for_tstate_lock(timeout=max(timeout, 0))
#   File "/opt/conda/lib/python3.10/threading.py", line 1116, in _wait_for_tstate_lock
#     if lock.acquire(block, timeout):
# KeyboardInterrupt
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/conda/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/distributed/process.py", line 202, in _run
#     target(*args, **kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/distributed/nanny.py", line 973, in _run
#     with contextlib.ExitStack() as stack:
#   File "/opt/conda/lib/python3.10/contextlib.py", line 576, in __exit__
#     raise exc_details[1]
#   File "/opt/conda/lib/python3.10/contextlib.py", line 561, in __exit__
#     if cb(*exc_details):
#   File "/opt/conda/lib/python3.10/contextlib.py", line 449, in _exit_wrapper
#     callback(*args, **kwds)
#   File "/opt/conda/lib/python3.10/threading.py", line 1100, in join
#     self._wait_for_tstate_lock(timeout=max(timeout, 0))
#   File "/opt/conda/lib/python3.10/threading.py", line 1116, in _wait_for_tstate_lock
#     if lock.acquire(block, timeout):
# KeyboardInterrupt
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/distributed/nanny.py", line 999, in _run
#     asyncio.run(run())
#   File "/opt/conda/lib/python3.10/asyncio/runners.py", line 44, in run
#     return loop.run_until_complete(main)
#   File "/opt/conda/lib/python3.10/asyncio/base_events.py", line 636, in run_until_complete
#     self.run_forever()
#   File "/opt/conda/lib/python3.10/site-packages/distributed/nanny.py", line 999, in _run
#     asyncio.run(run())
#   File "/opt/conda/lib/python3.10/asyncio/base_events.py", line 603, in run_forever
#     self._run_once()
#   File "/opt/conda/lib/python3.10/asyncio/runners.py", line 44, in run
#     return loop.run_until_complete(main)
#   File "/opt/conda/lib/python3.10/asyncio/base_events.py", line 1871, in _run_once
#     event_list = self._selector.select(timeout)
#   File "/opt/conda/lib/python3.10/asyncio/base_events.py", line 636, in run_until_complete
#     self.run_forever()
#   File "/opt/conda/lib/python3.10/selectors.py", line 469, in select
#     fd_event_list = self._selector.poll(timeout, max_ev)
#   File "/opt/conda/lib/python3.10/asyncio/base_events.py", line 603, in run_forever
#     self._run_once()
#   File "/opt/conda/lib/python3.10/asyncio/base_events.py", line 1909, in _run_once
#     handle._run()
#   File "/opt/conda/lib/python3.10/asyncio/events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
# KeyboardInterrupt
#   File "/opt/conda/lib/python3.10/site-packages/tornado/ioloop.py", line 747, in _run_callback
#     ret = gen.convert_yielded(ret)
#
# During handling of the above exception, another exception occurred:
#
#   File "/opt/conda/lib/python3.10/functools.py", line 889, in wrapper
#     return dispatch(args[0].__class__)(*args, **kw)
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/tornado/gen.py", line 878, in convert_yielded
#     return _wrap_awaitable(yielded)  # type: ignore
#   File "/opt/conda/lib/python3.10/asyncio/tasks.py", line 615, in ensure_future
#     return _ensure_future(coro_or_future, loop=loop)
#   File "/opt/conda/lib/python3.10/asyncio/tasks.py", line 636, in _ensure_future
#     return loop.create_task(coro_or_future)
#   File "/opt/conda/lib/python3.10/asyncio/base_events.py", line 438, in create_task
#     task = tasks.Task(coro, loop=self, name=name)
#   File "/opt/conda/lib/python3.10/asyncio/base_events.py", line 757, in call_soon
#     handle = self._call_soon(callback, args, context)
#   File "/opt/conda/lib/python3.10/asyncio/base_events.py", line 773, in _call_soon
#     handle = events.Handle(callback, args, self, context)
#   File "/opt/conda/lib/python3.10/asyncio/events.py", line 31, in __init__
#     def __init__(self, callback, args, loop, context=None):
#   File "/opt/conda/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
# KeyboardInterrupt
#   File "/opt/conda/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#
# During handling of the above exception, another exception occurred:
#
#   File "/opt/conda/lib/python3.10/site-packages/distributed/process.py", line 202, in _run
#     target(*args, **kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/distributed/nanny.py", line 973, in _run
#     with contextlib.ExitStack() as stack:
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/contextlib.py", line 576, in __exit__
#     raise exc_details[1]
#   File "/opt/conda/lib/python3.10/contextlib.py", line 561, in __exit__
#     if cb(*exc_details):
#   File "/opt/conda/lib/python3.10/contextlib.py", line 449, in _exit_wrapper
#     callback(*args, **kwds)
#   File "/opt/conda/lib/python3.10/threading.py", line 1100, in join
#     self._wait_for_tstate_lock(timeout=max(timeout, 0))
#   File "/opt/conda/lib/python3.10/threading.py", line 1116, in _wait_for_tstate_lock
#     if lock.acquire(block, timeout):
# KeyboardInterrupt
#   File "/opt/conda/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/conda/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/distributed/process.py", line 202, in _run
#     target(*args, **kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/distributed/nanny.py", line 973, in _run
#     with contextlib.ExitStack() as stack:
#   File "/opt/conda/lib/python3.10/contextlib.py", line 576, in __exit__
#     raise exc_details[1]
#   File "/opt/conda/lib/python3.10/contextlib.py", line 561, in __exit__
#     if cb(*exc_details):
#   File "/opt/conda/lib/python3.10/contextlib.py", line 449, in _exit_wrapper
#     callback(*args, **kwds)
#   File "/opt/conda/lib/python3.10/threading.py", line 1100, in join
#     self._wait_for_tstate_lock(timeout=max(timeout, 0))
#   File "/opt/conda/lib/python3.10/threading.py", line 1116, in _wait_for_tstate_lock
#     if lock.acquire(block, timeout):
# KeyboardInterrupt
# sys:1: RuntimeWarning: coroutine 'PeriodicCallback._run' was never awaited
# RuntimeWarning: Enable tracemalloc to get the object allocation traceback
# Task was destroyed but it is pending!
# task: <Task pending name='Task-124758' coro=<PeriodicCallback._run() running at /opt/conda/lib/python3.10/site-packages/tornado/ioloop.py:915>>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[27], line 8
#       6 while True:
#       7     try:
# ----> 8         del_msg = del_consumer.poll(1.0)
#      10         if del_msg is not None:
#      11             id = del_msg.value().decode('utf-8')
#
# KeyboardInterrupt:
